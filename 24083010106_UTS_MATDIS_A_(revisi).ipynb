# %% [markdown]
# Nama : Yuniar Rachmawati
#
# NPM : 24083010106
#
# Mata Kuliah : MATEMATIKA DISKRIT A
#
# **TUGAS PENGGANTI UTS**

# %% [markdown]
# **ARTIKEL**
#
# * JUDUL : **Efektivitas Penyuluhan Kesehatan dalam Meningkatkan Pengetahuan Wanita Usia Subur tentang Stunting di Desa Pamekaran, Kabupaten Sumedang**
# * DOI : https://doi.org/10.52436/1.jpmi.3427
# * Corresponding Author berasal dari: Indonesia
#
# **Cuplikan Artikel**
# * Abstrak
#
#   Stunting  adalah  masalah  kesehatan  serius  yang  berdampak  jangka  panjang  pada  pertumbuhan anak-anak,  terutama  di  wilayah  Cimacan.  Pengabdian  kepada  Masyarakat  (PkM)  ini  bertujuan  untuk mengevaluasi efektivitas pendidikan kesehatan dalam meningkatkan pengetahuan wanita usia subur (WUS) tentang  stunting.  Penelitian  ini  menggunakan  metode  penyuluhan  kesehatan  yang  melibatkan  16  peserta WUS, dengan waktu pelaksaan sekitar satu jam. Penyuluhan berlangsung dalam tiga sesi: pengisian pre-test, pemaparan   materi   dan   diskusi,   serta   pengisian   kuosioner   post-test.   Data   dianalisis   dengan   uji   t-test berpasangan untuk mengukur perubahan skor pengetahuan. Hasil penelitian menunjukkan peningkatan skor rata-rata   dari   pre-test   (M=71,875;   SD=16,419)   ke   post-test   (M=83,125;   SD=9,465).   Analisis   statistik menunjukkan  hasil  yang  signifikan  (p=0,017  <  0,05),  yang  menunjukkan  peningkatan  pemahaman  peserta mengenai   stunting.   Kesimpulannya,   pendidikan   kesehatan   berkontribusi   positif   terhadap   peningkatan kesadaran  WUS  tentang  stunting.  Temuan  ini  menekankan  pentingnya  edukasi  yang  efektif  dalam  upaya pencegahan stunting.
# * Pendahuluan
#
#   Stunting  merupakan  kondisi  di  mana  tinggi  badan  anak  lebih  rendah  dibandingkan dengan rata-rata anak seusianya, yang disebabkan oleh kekurangan gizi dalam waktu yang lama [1].  Kondisi  ini  umumnya  disebabkan  oleh  kurangnya  gizi  yang  diterima  ibu  selama  kehamilan atau  kekurangan  gizi  pada  anak  sepanjang  masa  pertumbuhannya [2].  Menurut  Kementerian Kesehatan tahun 2024, stunting terjadi karena kekurangan gizi yang berlangsung lama, dimulai semenjak bayi masih berada dalam kandungan hingga mencapai usia dua tahun [3]. Berdasarkan Survei Kesehatan Indonesia tahun 2023, prevalensi stunting di Indonesia tercatat sebesar 21,5%, meskipun ada penurunan dibandingkan dengan tahun 2021 yang mencapai 24,4%. Namun, angka prevalensi ini masih tergolong tinggi di Indonesia.
#
#   Masalah  ini  menjadi  perhatian  utama karena  prevalensi  stunting  yang  masih  tinggi, meskipun  ada  upaya  yang  terus  dilakukan  untuk  menurunkannya.  Menurut  data  dari  Survei Kesehatan  Indonesia  (SKI)[4],  prevalensi  stunting  nasional  tercatat  sebesar  21,5%,  meskipun menunjukkan   penurunan dibandingkan   tahun   sebelumnya.   Di   tingkat   daerah,   seperti   di Kabupaten  Sumedang,  prevalensi  stunting  mengalami  penurunan  yang  signifikan,  dari  27,6% pada tahun 2022 menjadi 14,4% pada tahun 2023 [4]. Di Rancakalong, prevalensi stunting pada tahun   2019   tercatat   sebesar   19,8%,   berdasarkan   data   yang   dikeluarkan   oleh   Puskesmas Rancakalong. Sementara itu, angka stunting di Desa Pamekaran pada tahun 2024 tercatat sebesar 6%.  Namun,  masih  ada  tantangan  besar  untuk  memastikan  bahwa  semua  anak,  terutama  yang berada di bawah lima tahun, mendapatkan asupan gizi yang memadai, mengingat ada indikator yang masih menunjukkan angka rendah, seperti pada pemenuhan tambahan asupan gizi[5].
#
#   Urgensi  masalah  stunting  sangat  tinggi  karena  dampak  jangka  panjangnya  terhadap kesehatan, pendidikan, dan perekonomian suatu negara[6]. Stunting bukan hanya menghambat pertumbuhan fisik anak, tetapi juga mempengaruhi kemampuan kognitifnya, yang pada akhirnya berdampak pada kualitas tenaga kerja di masa depan [7]. Oleh karena itu, percepatan penurunan angka  stunting  menjadi  sangat  mendesak.  Tantangan  dalam  menurunkan  prevalensi  stunting masih  ada [8].  Pemantauan  layanan  esensial  melalui  aplikasi  SIMPATI  menunjukkan  perbaikan pada sebagian besar indikator percepatan penurunan stunting. Meski demikian, indikator terkait persentase  anak  berusia  lima  tahun  yang  mengalami  kekurangan  gizi  dan  menerima  tambahan asupan gizi masih rendah[9][10]. Upaya lebih lanjut diperlukan untuk memastikan bahwa semua balita   memperoleh   asupan   gizi   yang   cukup   dan   seimbang   guna   mendukung   percepatan penurunan stunting[11].
#
#   Penelitian yang dilakukan oleh [7]tentang program "Gempur Stunting" yang diinisiasi oleh Puskesmas Rancakalong, Kabupaten Sumedang, menunjukkan hasil yang sangat positif. Program ini  berhasil  menurunkan  prevalensi  stunting  di  wilayah  tersebut  dari  27,7%  pada  tahun  2018 menjadi  19,8%  pada  tahun  2019. Kegiatan  Pengabdian  kepada  Masyarakat  (PkM)  ini  secara spesifik menargetkan peningkatan pengetahuan masyarakat Desa Cimacan, sebuah wilayah yang menghadapi tantangan signifikan terkait stunting, mengenai pencegahan dan penanganan kondisi tersebut. Stunting, sebagai gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi  kronis,  menjadi  perhatian  serius  di  Indonesia,  termasuk  di  tingkat  desa. Keberhasilan program "Gempur Stunting" di Rancakalong, Sumedang yang mampu menurunkan angka stunting melalui sosialisasi, kerjasama lintas sektor, dan pemberian makanan tambahan.
#
#   Menurut    penelitian [12]yang    membahas    tentang    Edukasi    kesehatan    mengenai pencegahan  stunting  untuk  masyarakat,  kader,  dan  guru  kelompok  bermain  di  Desa  Cijambu, Tanjungsari, Sumedang. Penyuluhan kesehatan dengan tema “Pencegahan Stunting Sejak Masa Kehamilan” melibatkan 56 peserta  yang  terdiri  atas  kader,  guru  prasekolah,  ibu  hamil,  dan  ibu dengan  balita,  dilaksanakan  melalui  metode  ceramah  dengan  menggunakan  media  seperti PowerPoint, leaflet, dan poster. Hasil kuesioner menunjukkan bahwa dari dari 31 ibu, 16 orang memiliki  tingkat  pengetahuan  yang  baik  dengan  sikap  positif,  11  orang  memiliki  pengetahuan yang  cukup  dan  tetap  bersikap  positif,  sementara  4  orang  lainnya  memiliki  pengetahuan  yang kurang  namun  menunjukkan  sikap  yang  positif,  dengan  nilai  p  value  sebesar  0,009.  Secara keseluruhan,   mayoritas   ibu   (60,8%   atau   31   orang)   menunjukkan   sikap   positif   terhadap pencegahan  stunting.  Penelitian  ini  menyoroti  pentingnya  sinergi  edukasi  formal  dan  informal serta  penggunaan  media  dalam  pencegahan  stunting.Hal  ini yang  menunjukkan  efektivitas edukasi  kesehatan  dalam  meningkatkan  pengetahuan  dan  sikap  positif  masyarakat  terhadap pencegahan  stunting,  PkM  ini  bertujuan  untuk  mengadaptasi  dan  menerapkan  strategi  serupa yang relevan dengan konteks Desa Cimacan.Kondisi stunting di Desa Cimacan, meskipun belum terukur  secara  spesifik  dalam  paparan  ini,  dapat  diasumsikan  memiliki  karakteristik  umum seperti  kurangnya  pemahaman  masyarakat  mengenai  gizi  seimbang,  praktik  pemberian  makan bayi  dan  anak  yang  tidak  optimal,  serta  sanitasi  dan  akses  air  bersih  yang  kurang  memadai. Keterbatasan  akses  informasi  yang  akurat  dan  relevan  mengenai  stunting  juga  menjadi  faktor penghambat  upaya  pencegahan.  Oleh  karena  itu,  intervensi  yang  berfokus  pada  peningkatan pengetahuan  masyarakat  menjadi  langkah  awal  yang  krusial.  Penelitian-penelitian  sebelumnya menunjukkan bahwa edukasi yang efektif, didukung oleh kerjasama lintas sektor dan penggunaan media  yang  tepat,  dapat  memberikan  dampak  positif  dalam  meningkatkan  kesadaran  dan mengubah perilaku masyarakat terkait stunting.
#
#   Untuk  mencapai  tujuan  PkM  ini,  yaitu  mengetahui  efektivitas  penyuluhan  kesehatan dalam  meningkatkan  pengetahuan  masyarakat  Desa  Cimacan  terkait  stunting,  kegiatan  akan dirancang  dengan  fokus pada  penyampaian  informasi  yang jelas, mudah  dipahami,  dan  relevan dengan  kondisi  lokal.  Solusi  yang  diusulkan  adalah  pelaksanaan  serangkaian  kegiatan  edukasi kesehatan   yang   komprehensif,   meliputi   penyuluhan   langsung   dengan   melibatkan   tokoh masyarakat dan kader kesehatan setempat, pemanfaatan media komunikasi yang efektif seperti poster   dan   leaflet   berbahasa   lokal,   serta   diskusi   kelompok   terarah   untuk   memperdalam pemahaman  dan  menjawab  pertanyaan.  Evaluasi  akan  dilakukan  melalui  pengukuran  tingkat pengetahuan  peserta  sebelum  dan  sesudah  penyuluhan  untuk  mengukur  dampak  intervensi secara  kuantitatif.  Dengan  demikian,  PkM  ini  diharapkan  dapat  memberikan  kontribusi  nyata dalam  meningkatkan   pemahaman   masyarakat   Desa   Cimacan   mengenai  stunting   dan   pada akhirnya mendukung upaya pencegahan dan penanganannya di tingkat desa.
#
# * Kesimpulan
#
#   Pendidikan kesehatan tentang stunting yang dilaksanakan di Posyandu Merpati III, Dusun Cimacan, Desa Pamekaran, terbukti efektif meningkatkan pengetahuan wanita usia subur (WUS). Hasil  pre-test  dan  post-test  menunjukkan  peningkatan  rata-rata  skor  pengetahuan  dari  71,88 menjadi  83,13,  serta  peningkatan  proporsi  responden  dengan  kategori  pengetahuan  baik  dari 12,5% menjadi 43,75%. Uji Wilcoxon menunjukkan peningkatan ini signifikan secara statistik (p-value = 0,017 < 0,05), menandakan bahwa penyuluhan yang diberikan berdampak nyata terhadap peningkatan pengetahuan.
#
#   Berdasarkan  temuan  ini,  disarankan  agar  program  pendidikan  kesehatan  serupa  terus dilaksanakan dan dikembangkan dengan metode yang lebih interaktif, seperti diskusi kelompok, simulasi,  atau  penggunaanmedia  audio-visual.  Pendekatan  tersebut  diharapkan  dapat  semakin meningkatkan   pemahaman   dan   keterlibatan   peserta,   sehingga   upaya   pencegahan   stunting menjadi lebih optimal.

# %%
import re
import string
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import sent_tokenize, word_tokenize
from wordcloud import WordCloud
import nltk
nltk.download('punkt')

# ===============================================================
# 📄 INFORMASI ARTIKEL
# ===============================================================

article_info = {
    "Judul": "Efektivitas Penyuluhan Kesehatan dalam Meningkatkan Pengetahuan Wanita Usia Subur tentang Stunting di Desa Pamekaran, Kabupaten Sumedang",
    "Penulis": [
        "Mahyati",
        "Pasha Aprillya Andriyansyah",
        "Rieke Kartika Winata",
        "Shelpi Anggraeni",
        "Syafira Az Hara Ariesta",
        "Ria Inriyana",
        "Endang Kusuma Dewi"
    ],
    "Institusi": "Prodi S1 Keperawatan, Universitas Pendidikan Indonesia, Kampus Sumedang",
    "Lokasi Penelitian": "Desa Pamekaran, Kecamatan Rancakalong, Kabupaten Sumedang",
    "Negara": "Indonesia",
    "DOI": "https://doi.org/10.52436/jpmi.v5i4.3427",
    "Status DOI": "✅ VALID",
    "Jurnal": "Jurnal Pengabdian Masyarakat Indonesia (JPMI)",
    "Volume": "Vol. 5, No. 4, Agustus 2025",
    "Halaman": "1067–1075",
    "Tanggal": "Agustus 2025"
}

print("="*70)
print("📘 INFORMASI ARTIKEL\n")
print(f"Judul : {article_info['Judul']}\n")
print("Penulis:")
for author in article_info["Penulis"]:
    print(f" • {author}")
print(f"\nInstitusi        : {article_info['Institusi']}")
print(f"Lokasi Penelitian: {article_info['Lokasi Penelitian']}")
print(f"Negara           : {article_info['Negara']}")
print(f"DOI              : {article_info['DOI']}  {article_info['Status DOI']}")
print(f"Jurnal           : {article_info['Jurnal']}")
print(f"Volume           : {article_info['Volume']}")
print(f"Halaman          : {article_info['Halaman']}")
print(f"Tanggal          : {article_info['Tanggal']}")
print("="*70)


# ===============================
# 1. MASUKKAN TEKS ARTIKEL
# ===============================

text = """
ABSTRAK
[Stunting adalah masalah kesehatan serius yang berdampak jangka panjang pada pertumbuhan anak-anak, terutama di wilayah Cimacan. Pengabdian kepada Masyarakat (PkM) ini bertujuan untuk mengevaluasi efektivitas pendidikan kesehatan dalam meningkatkan pengetahuan wanita usia subur (WUS) tentang stunting. Penelitian ini menggunakan metode penyuluhan kesehatan yang melibatkan 16 peserta WUS, dengan waktu pelaksaan sekitar satu jam. Penyuluhan berlangsung dalam tiga sesi: pengisian pre-test, pemaparan materi dan diskusi, serta pengisian kuosioner post-test. Data dianalisis dengan uji t-test berpasangan untuk mengukur perubahan skor pengetahuan. Hasil penelitian menunjukkan peningkatan skor rata-rata dari pre-test (M=71,875; SD=16,419) ke post-test (M=83,125; SD=9,465). Analisis statistik menunjukkan hasil yang signifikan (p=0,017 < 0,05), yang menunjukkan peningkatan pemahaman peserta mengenai stunting. Kesimpulannya, pendidikan kesehatan berkontribusi positif terhadap peningkatan kesadaran WUS tentang stunting. Temuan ini menekankan pentingnya edukasi yang efektif dalam upaya pencegahan stunting.]

PENDAHULUAN
[Stunting merupakan kondisi di mana tinggi badan anak lebih rendah dibandingkan dengan rata-rata anak seusianya, yang disebabkan oleh kekurangan gizi dalam waktu yang lama [1]. Kondisi ini umumnya disebabkan oleh kurangnya gizi yang diterima ibu selama kehamilan atau kekurangan gizi pada anak sepanjang masa pertumbuhannya [2]. Menurut Kementerian Kesehatan tahun 2024, stunting terjadi karena kekurangan gizi yang berlangsung lama, dimulai semenjak bayi masih berada dalam kandungan hingga mencapai usia dua tahun [3]. Berdasarkan Survei Kesehatan Indonesia tahun 2023, prevalensi stunting di Indonesia tercatat sebesar 21,5%, meskipun ada penurunan dibandingkan dengan tahun 2021 yang mencapai 24,4%. Namun, angka prevalensi ini masih tergolong tinggi di Indonesia.

Masalah ini menjadi perhatian utama karena prevalensi stunting yang masih tinggi, meskipun ada upaya yang terus dilakukan untuk menurunkannya. Menurut data dari Survei Kesehatan Indonesia (SKI)[4], prevalensi stunting nasional tercatat sebesar 21,5%, meskipun menunjukkan penurunan dibandingkan tahun sebelumnya. Di tingkat daerah, seperti di Kabupaten Sumedang, prevalensi stunting mengalami penurunan yang signifikan, dari 27,6% pada tahun 2022 menjadi 14,4% pada tahun 2023 [4]. Di Rancakalong, prevalensi stunting pada tahun 2019 tercatat sebesar 19,8%, berdasarkan data yang dikeluarkan oleh Puskesmas Rancakalong. Sementara itu, angka stunting di Desa Pamekaran pada tahun 2024 tercatat sebesar 6%. Namun, masih ada tantangan besar untuk memastikan bahwa semua anak, terutama yang berada di bawah lima tahun, mendapatkan asupan gizi yang memadai, mengingat ada indikator yang masih menunjukkan angka rendah, seperti pada pemenuhan tambahan asupan gizi[5].

Urgensi masalah stunting sangat tinggi karena dampak jangka panjangnya terhadap kesehatan, pendidikan, dan perekonomian suatu negara[6]. Stunting bukan hanya menghambat pertumbuhan fisik anak, tetapi juga mempengaruhi kemampuan kognitifnya, yang pada akhirnya berdampak pada kualitas tenaga kerja di masa depan [7]. Oleh karena itu, percepatan penurunan angka stunting menjadi sangat mendesak. Tantangan dalam menurunkan prevalensi stunting masih ada [8]. Pemantauan layanan esensial melalui aplikasi SIMPATI menunjukkan perbaikan pada sebagian besar indikator percepatan penurunan stunting. Meski demikian, indikator terkait persentase anak berusia lima tahun yang mengalami kekurangan gizi dan menerima tambahan asupan gizi masih rendah[9][10]. Upaya lebih lanjut diperlukan untuk memastikan bahwa semua balita memperoleh asupan gizi yang cukup dan seimbang guna mendukung percepatan penurunan stunting[11].

Penelitian yang dilakukan oleh [7]tentang program "Gempur Stunting" yang diinisiasi oleh Puskesmas Rancakalong, Kabupaten Sumedang, menunjukkan hasil yang sangat positif. Program ini berhasil menurunkan prevalensi stunting di wilayah tersebut dari 27,7% pada tahun 2018 menjadi 19,8% pada tahun 2019. Kegiatan Pengabdian kepada Masyarakat (PkM) ini secara spesifik menargetkan peningkatan pengetahuan masyarakat Desa Cimacan, sebuah wilayah yang menghadapi tantangan signifikan terkait stunting, mengenai pencegahan dan penanganan kondisi tersebut. Stunting, sebagai gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis, menjadi perhatian serius di Indonesia, termasuk di tingkat desa. Keberhasilan program "Gempur Stunting" di Rancakalong, Sumedang yang mampu menurunkan angka stunting melalui sosialisasi, kerjasama lintas sektor, dan pemberian makanan tambahan.

Menurut penelitian [12]yang membahas tentang Edukasi kesehatan mengenai pencegahan stunting untuk masyarakat, kader, dan guru kelompok bermain di Desa Cijambu, Tanjungsari, Sumedang. Penyuluhan kesehatan dengan tema “Pencegahan Stunting Sejak Masa Kehamilan” melibatkan 56 peserta yang terdiri atas kader, guru prasekolah, ibu hamil, dan ibu dengan balita, dilaksanakan melalui metode ceramah dengan menggunakan media seperti PowerPoint, leaflet, dan poster. Hasil kuesioner menunjukkan bahwa dari dari 31 ibu, 16 orang memiliki tingkat pengetahuan yang baik dengan sikap positif, 11 orang memiliki pengetahuan yang cukup dan tetap bersikap positif, sementara 4 orang lainnya memiliki pengetahuan yang kurang namun menunjukkan sikap yang positif, dengan nilai p value sebesar 0,009. Secara keseluruhan, mayoritas ibu (60,8% atau 31 orang) menunjukkan sikap positif terhadap pencegahan stunting. Penelitian ini menyoroti pentingnya sinergi edukasi formal dan informal serta penggunaan media dalam pencegahan stunting.Hal ini yang menunjukkan efektivitas edukasi kesehatan dalam meningkatkan pengetahuan dan sikap positif masyarakat terhadap pencegahan stunting, PkM ini bertujuan untuk mengadaptasi dan menerapkan strategi serupa yang relevan dengan konteks Desa Cimacan.Kondisi stunting di Desa Cimacan, meskipun belum terukur secara spesifik dalam paparan ini, dapat diasumsikan memiliki karakteristik umum seperti kurangnya pemahaman masyarakat mengenai gizi seimbang, praktik pemberian makan bayi dan anak yang tidak optimal, serta sanitasi dan akses air bersih yang kurang memadai. Keterbatasan akses informasi yang akurat dan relevan mengenai stunting juga menjadi faktor penghambat upaya pencegahan. Oleh karena itu, intervensi yang berfokus pada peningkatan pengetahuan masyarakat menjadi langkah awal yang krusial. Penelitian-penelitian sebelumnya menunjukkan bahwa edukasi yang efektif, didukung oleh kerjasama lintas sektor dan penggunaan media yang tepat, dapat memberikan dampak positif dalam meningkatkan kesadaran dan mengubah perilaku masyarakat terkait stunting.

Untuk mencapai tujuan PkM ini, yaitu mengetahui efektivitas penyuluhan kesehatan dalam meningkatkan pengetahuan masyarakat Desa Cimacan terkait stunting, kegiatan akan dirancang dengan fokus pada penyampaian informasi yang jelas, mudah dipahami, dan relevan dengan kondisi lokal. Solusi yang diusulkan adalah pelaksanaan serangkaian kegiatan edukasi kesehatan yang komprehensif, meliputi penyuluhan langsung dengan melibatkan tokoh masyarakat dan kader kesehatan setempat, pemanfaatan media komunikasi yang efektif seperti poster dan leaflet berbahasa lokal, serta diskusi kelompok terarah untuk memperdalam pemahaman dan menjawab pertanyaan. Evaluasi akan dilakukan melalui pengukuran tingkat pengetahuan peserta sebelum dan sesudah penyuluhan untuk mengukur dampak intervensi secara kuantitatif. Dengan demikian, PkM ini diharapkan dapat memberikan kontribusi nyata dalam meningkatkan pemahaman masyarakat Desa Cimacan mengenai stunting dan pada akhirnya mendukung upaya pencegahan dan penanganannya di tingkat desa.]

KESIMPULAN
[Pendidikan kesehatan tentang stunting yang dilaksanakan di Posyandu Merpati III, Dusun Cimacan, Desa Pamekaran, terbukti efektif meningkatkan pengetahuan wanita usia subur (WUS). Hasil pre-test dan post-test menunjukkan peningkatan rata-rata skor pengetahuan dari 71,88 menjadi 83,13, serta peningkatan proporsi responden dengan kategori pengetahuan baik dari 12,5% menjadi 43,75%. Uji Wilcoxon menunjukkan peningkatan ini signifikan secara statistik (p-value = 0,017 < 0,05), menandakan bahwa penyuluhan yang diberikan berdampak nyata terhadap peningkatan pengetahuan.

Berdasarkan temuan ini, disarankan agar program pendidikan kesehatan serupa terus dilaksanakan dan dikembangkan dengan metode yang lebih interaktif, seperti diskusi kelompok, simulasi, atau penggunaanmedia audio-visual. Pendekatan tersebut diharapkan dapat semakin meningkatkan pemahaman dan keterlibatan peserta, sehingga upaya pencegahan stunting menjadi lebih optimal.]
"""

# ===============================
# 2. DETEKSI BAGIAN ARTIKEL
# ===============================

pattern = r'\b(ABSTRAK|ABSTRACT|PENDAHULUAN|INTRODUCTION|KESIMPULAN|CONCLUSION)\b'
parts = re.split(pattern, text, flags=re.IGNORECASE)

sections = {}
for i in range(1, len(parts) - 1, 2):
    section_name = parts[i].strip().capitalize()
    section_text = parts[i + 1].strip()
    sections[section_name] = section_text

print("Bagian yang terdeteksi:", list(sections.keys()))
print("="*70)

# ===============================
# 3. FUNGSI PEMBANTU
# ===============================

def clean_word(w):
    return w.strip(string.punctuation + "“”‘’—…").lower()

def count_vowels_consonants(word):
    vowels = "aeiou"
    v, c = 0, 0
    for ch in word:
        if ch.isalpha():
            if ch in vowels:
                v += 1
            else:
                c += 1
    return c, v
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ======================================================================
# 📘 INFORMASI ARTIKEL
#
# Judul : Efektivitas Penyuluhan Kesehatan dalam Meningkatkan Pengetahuan Wanita Usia Subur tentang Stunting di Desa Pamekaran, Kabupaten Sumedang
#
# Penulis:
#  • Mahyati
#  • Pasha Aprillya Andriyansyah
#  • Rieke Kartika Winata
#  • Shelpi Anggraeni
#  • Syafira Az Hara Ariesta
#  • Ria Inriyana
#  • Endang Kusuma Dewi
#
# Institusi        : Prodi S1 Keperawatan, Universitas Pendidikan Indonesia, Kampus Sumedang
# Lokasi Penelitian: Desa Pamekaran, Kecamatan Rancakalong, Kabupaten Sumedang
# Negara           : Indonesia
# DOI              : https://doi.org/10.52436/jpmi.v5i4.3427  ✅ VALID
# Jurnal           : Jurnal Pengabdian Masyarakat Indonesia (JPMI)
# Volume           : Vol. 5, No. 4, Agustus 2025
# Halaman          : 1067–1075
# Tanggal          : Agustus 2025
# ======================================================================
# Bagian yang terdeteksi: ['Abstrak', 'Pendahuluan', 'Kesimpulan']
# ======================================================================

# %%
# ===============================================================
# 🧩 TUGAS 1: TABULASI KONSONAN - VOKAL
# ===============================================================

all_words = []
for section, content in sections.items():
    words = [clean_word(w) for w in re.findall(r'\b\w+\b', content)]
    for w in words:
        cons, vows = count_vowels_consonants(w)
        all_words.append({
            "section": section,
            "word": w,
            "consonants": cons,
            "vowels": vows
        })

df_words = pd.DataFrame(all_words)

print("\n=== TUGAS 1: TABULASI KONSONAN & VOKAL ===")

# --- Gabungan seluruh bagian ---
pivot_freq = df_words.groupby(["consonants", "vowels"]).size().unstack(fill_value=0)
pivot_unique = df_words.groupby(["consonants", "vowels"])["word"].nunique().unstack(fill_value=0)

print("\nTABEL PIVOT (Frekuensi Gabungan):")
print(pivot_freq)
print("\nTABEL PIVOT (Kata Unik Gabungan):")
print(pivot_unique)

# --- Heatmap gabungan ---
plt.figure(figsize=(6, 4))
sns.heatmap(pivot_freq, cmap="Blues", annot=True, fmt="d")
plt.title("Distribusi Frekuensi Konsonan-Vokal")
plt.xlabel("Jumlah Vokal")
plt.ylabel("Jumlah Konsonan")
plt.show()

plt.figure(figsize=(6, 4))
sns.heatmap(pivot_unique, cmap="YlGnBu", annot=True, fmt="d")
plt.title("Distribusi Cacah Kata Unik Konsonan-Vokal")
plt.xlabel("Jumlah Vokal")
plt.ylabel("Jumlah Konsonan")
plt.show()
# Out:
# === TUGAS 1: TABULASI KONSONAN & VOKAL ===
#
# TABEL PIVOT (Frekuensi Gabungan):
# vowels       0   1    2   3   4   5  6  7
# consonants
# 0           75   0    0   1   0   0  0  0
# 1            6  19   33   6   1   0  0  0
# 2            2  39   98  18   0   0  0  0
# 3            5  60  121  47  15   1  0  0
# 4            0   0   47  94  34   8  1  0
# 5            0   0   18  53  69  11  1  0
# 6            0   0   38  20  91  26  2  0
# 7            0   0    0   5  41   8  0  0
# 8            0   0    0   2  13   5  0  1
# 9            0   0    0   0   0   1  0  0
#
# TABEL PIVOT (Kata Unik Gabungan):
# vowels       0  1   2   3   4   5  6  7
# consonants
# 0           41  0   0   1   0   0  0  0
# 1            3  2   7   2   1   0  0  0
# 2            1  6  26   8   0   0  0  0
# 3            1  4  43  25   6   1  0  0
# 4            0  0  17  37  20   4  1  0
# 5            0  0   7  30  29   5  1  0
# 6            0  0   2  12  34  11  2  0
# 7            0  0   0   4  12   6  0  0
# 8            0  0   0   1   5   5  0  1
# 9            0  0   0   0   0   1  0  0

# %% [markdown]
# **INTERPRETASI KONSONAN-VOKAL**
#
# 1. Kombinasi Konsonan–Vokal dalam Kata (Berdasarkan Frekuensi Total)
#
#   Hasil tabulasi menunjukkan bahwa pola penggunaan huruf dalam seluruh artikel (abstrak, introduction, dan conclusion) didominasi oleh kata dengan 2–4 huruf vokal dan 3–6 huruf konsonan.
#
#   Kombinasi (vokal = 3, konsonan = 4) menjadi yang paling sering muncul dengan frekuensi 121 kali.
#
#   Kombinasi lain yang tinggi antara lain:
#
# (vokal = 2, konsonan = 3) sebanyak 98 kata
#
# (vokal = 2, konsonan = 4) sebanyak 94 kata
#
# (vokal = 3, konsonan = 5) sebanyak 69 kata
#
# (vokal = 3, konsonan = 6) sebanyak 91 kata
#
# Sebaliknya, kombinasi ekstrem seperti:
#
# - (vokal = 0–1) hanya muncul pada kata pendek atau singkatan seperti “di”, “ke”, “dari”, yang memiliki frekuensi di bawah 20 kali.
# - (vokal ≥ 6) atau (konsonan ≥ 8) hampir tidak ditemukan (frekuensi < 5).
#
# Distribusi ini menggambarkan bahwa keseluruhan artikel didominasi oleh kata-kata dengan panjang sedang (5–8 huruf) dan struktur huruf yang seimbang antara vokal dan konsonan. Hal ini mencerminkan ciri khas bahasa ilmiah yang berfokus pada kejelasan, konsistensi morfologi, dan keterbacaan tinggi.
#
# 2. Cacah Kata Unik per Kombinasi Konsonan–Vokal
#
#   Analisis kata unik menunjukkan pola serupa, namun dengan jumlah yang lebih kecil karena kata berulang dihitung satu kali saja.
#
# Kombinasi dengan jumlah kata unik terbanyak adalah:
#
# (vokal = 2, konsonan = 3) → 43 kata unik
#
# (vokal = 3, konsonan = 4) → 37 kata unik
#
# (vokal = 3, konsonan = 5) → 29 kata unik
#
# (vokal = 4, konsonan = 5) → 20 kata unik
#
# Sementara kombinasi dengan jumlah huruf ekstrem (vokal > 6 atau konsonan > 8) hampir tidak ditemukan, hanya 1–2 kata unik saja, misalnya istilah panjang seperti pencegahan atau peningkatan.
#
# Hal ini menunjukkan bahwa meskipun ada variasi leksikal, kebanyakan kata yang digunakan masih berasal dari bentuk dasar dan turunan umum, bukan istilah teknis panjang. Pola ini memperkuat kesimpulan bahwa struktur tulisan ilmiah pada artikel ini menjaga keseimbangan antara keragaman kosakata dan keterbacaan.

# %%
# ===============================================================
# 🧩 TUGAS 2: JUMLAH KATA DALAM KALIMAT
# ===============================================================

sentences_data = []
for section, content in sections.items():
    paragraphs = [p.strip() for p in re.split(r'\n\s*\n', content) if p.strip()]
    for pid, p in enumerate(paragraphs, start=1):
        sentences = sent_tokenize(p)
        for sid, s in enumerate(sentences, start=1):
            s_clean = re.sub(r'\s+', ' ', s.strip())
            word_count = len(word_tokenize(s_clean))
            sentences_data.append({
                "section": section,
                "paragraph_id": pid,
                "sentence_id": sid,
                "word_count": word_count
            })

df_sent = pd.DataFrame(sentences_data)

print("\n=== TUGAS 2: JUMLAH KATA DALAM KALIMAT ===\n")

for i, row in enumerate(df_sent.itertuples(), start=1):
    print(f"Kalimat ke-{i} terdapat {row.word_count} kata")

# Statistik ringkas per bagian
print("\nStatistik jumlah kata per bagian:\n")
print(df_sent.groupby("section")["word_count"].describe())

# =============================
# 🔹 Visualisasi Histogram
# =============================
plt.figure(figsize=(7,4))
sns.histplot(data=df_sent, x="word_count", color="pink", bins=10, edgecolor="black")
plt.title("Distribusi Jumlah Kata per Kalimat")
plt.xlabel("Jumlah Kata per Kalimat")
plt.ylabel("Jumlah Kalimat")
plt.show()

# =============================
# 🔹 Visualisasi WordCloud
# =============================

# Gabungkan semua teks dari semua kalimat
all_text = " ".join([
    re.sub(r'[^A-Za-zÀ-ÖØ-öø-ÿ ]', '', s)
    for s in df_sent["section"].map(lambda sec: sections[sec])
])

# Buat wordcloud
wordcloud = WordCloud(
    width=1000, height=600,
    background_color='white',
    colormap='Reds_r',
    collocations=False
).generate(all_text)

# Tampilkan
plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("WordCloud – Kata yang Paling Sering Muncul", fontsize=14)
plt.show()
# Out:
# === TUGAS 2: JUMLAH KATA DALAM KALIMAT ===
#
# Kalimat ke-1 terdapat 19 kata
# Kalimat ke-2 terdapat 25 kata
# Kalimat ke-3 terdapat 19 kata
# Kalimat ke-4 terdapat 19 kata
# Kalimat ke-5 terdapat 12 kata
# Kalimat ke-6 terdapat 21 kata
# Kalimat ke-7 terdapat 20 kata
# Kalimat ke-8 terdapat 13 kata
# Kalimat ke-9 terdapat 13 kata
# Kalimat ke-10 terdapat 30 kata
# Kalimat ke-11 terdapat 24 kata
# Kalimat ke-12 terdapat 31 kata
# Kalimat ke-13 terdapat 28 kata
# Kalimat ke-14 terdapat 11 kata
# Kalimat ke-15 terdapat 21 kata
# Kalimat ke-16 terdapat 28 kata
# Kalimat ke-17 terdapat 32 kata
# Kalimat ke-18 terdapat 21 kata
# Kalimat ke-19 terdapat 16 kata
# Kalimat ke-20 terdapat 45 kata
# Kalimat ke-21 terdapat 22 kata
# Kalimat ke-22 terdapat 29 kata
# Kalimat ke-23 terdapat 12 kata
# Kalimat ke-24 terdapat 11 kata
# Kalimat ke-25 terdapat 16 kata
# Kalimat ke-26 terdapat 28 kata
# Kalimat ke-27 terdapat 25 kata
# Kalimat ke-28 terdapat 28 kata
# Kalimat ke-29 terdapat 22 kata
# Kalimat ke-30 terdapat 33 kata
# Kalimat ke-31 terdapat 24 kata
# Kalimat ke-32 terdapat 27 kata
# Kalimat ke-33 terdapat 30 kata
# Kalimat ke-34 terdapat 45 kata
# Kalimat ke-35 terdapat 52 kata
# Kalimat ke-36 terdapat 19 kata
# Kalimat ke-37 terdapat 94 kata
# Kalimat ke-38 terdapat 16 kata
# Kalimat ke-39 terdapat 17 kata
# Kalimat ke-40 terdapat 33 kata
# Kalimat ke-41 terdapat 40 kata
# Kalimat ke-42 terdapat 47 kata
# Kalimat ke-43 terdapat 19 kata
# Kalimat ke-44 terdapat 31 kata
# Kalimat ke-45 terdapat 29 kata
# Kalimat ke-46 terdapat 29 kata
# Kalimat ke-47 terdapat 27 kata
# Kalimat ke-48 terdapat 30 kata
# Kalimat ke-49 terdapat 20 kata
#
# Statistik jumlah kata per bagian:
#
#              count       mean        std   min   25%   50%   75%   max
# section
# Abstrak        9.0  17.888889   4.342938  12.0  13.0  19.0  20.0  25.0
# Kesimpulan     5.0  27.000000   4.062019  20.0  27.0  29.0  29.0  30.0
# Pendahuluan   35.0  28.771429  15.193044  11.0  20.0  28.0  31.5  94.0

# %% [markdown]
# **INTERPRETASI JUMLAH KATA per KALIMAT**
#
# 1. Abstrak memiliki kalimat paling pendek dan homogen (SD rendah), menunjukkan gaya penulisan ringkas dan fokus untuk menyampaikan inti penelitian.
# 2. Pendahuluan memiliki variasi panjang kalimat paling tinggi (SD 15,39), bahkan ada kalimat sangat panjang (94 kata). Ini wajar karena bagian ini menjelaskan latar belakang dan teori, yang sering memerlukan penjabaran lebih detail.
# 3. Kesimpulan sedikit lebih panjang dari abstrak, tetapi tetap konsisten (SD rendah), menandakan kalimatnya padat namun tetap mudah dipahami.
#
# Pada histogram, sebagian besar kalimat memiliki panjang antara 15–40 kata, dengan sedikit outlier panjang di pendahuluan.
#
# Kata yang paling dominan dalam seluruh artikel (abstrak, pendahuluan, dan kesimpulan) adalah:
#
# * “stunting” : kata paling besar, menjadi pusat topik penelitian.
# * “yang”, “dan”, “dengan”, “pada”, “di” : kata penghubung umum, menunjukkan struktur kalimat yang kompleks namun formal.
# * “gizi”, “pengetahuan”, “kesehatan”, “penyuluhan”, “dampak”, “prevalensi”, “desa”, “tahun” : kata kunci utama yang menjelaskan isi penelitian tentang edukasi kesehatan dan pencegahan stunting di tingkat desa.
# * “menunjukkan”, “berdampak”, “meningkatkan” : kata kerja utama yang menunjukkan hubungan sebab-akibat dan hasil penelitian.
#
# **Kesimpulannya, struktur kalimat di artikel ini efisien dan akademis, dengan panjang moderat yang mendukung keterbacaan ilmiah.**

# %%
# ===============================================================
# 🧩 TUGAS 3: JUMLAH KALIMAT PER PARAGRAF
# ===============================================================

para_data = []
for section, content in sections.items():
    paragraphs = [p.strip() for p in re.split(r'\n\s*\n', content) if p.strip()]
    for pid, p in enumerate(paragraphs, start=1):
        sent_count = len(sent_tokenize(p))
        para_data.append({
            "section": section,
            "paragraph_id": pid,
            "sentence_count": sent_count
        })

df_para = pd.DataFrame(para_data)

# =============================
# 🔹 OUTPUT TERSTRUKTUR PER BAGIAN
# =============================
print("\n=== TUGAS 3: JUMLAH KALIMAT PER PARAGRAF ===\n")

for section in df_para["section"].unique():
    sub_df = df_para[df_para["section"] == section]
    print(f"\n📘 Bagian: {section.capitalize()}")
    print(f"Jumlah paragraf: {len(sub_df)}\n")
    for i, row in enumerate(sub_df.itertuples(), start=1):
        print(f"➡️ Paragraf ke-{i} terdiri dari {row.sentence_count} kalimat")
    print("-" * 50)

# =============================
# 🔹 Visualisasi Histogram
# =============================
plt.figure(figsize=(7,4))
sns.histplot(
    data=df_para,
    x="sentence_count",
    bins=range(1, max(df_para["sentence_count"]) + 2),
    color="pink",
    edgecolor="black"
)
plt.title("Distribusi Jumlah Kalimat per Paragraf")
plt.xlabel("Jumlah Kalimat per Paragraf")
plt.ylabel("Frekuensi")
plt.show()
# Out:
# === TUGAS 3: JUMLAH KALIMAT PER PARAGRAF ===
#
#
# 📘 Bagian: Abstrak
# Jumlah paragraf: 1
#
# ➡️ Paragraf ke-1 terdiri dari 9 kalimat
# --------------------------------------------------
#
# 📘 Bagian: Pendahuluan
# Jumlah paragraf: 6
#
# ➡️ Paragraf ke-1 terdiri dari 5 kalimat
# ➡️ Paragraf ke-2 terdiri dari 6 kalimat
# ➡️ Paragraf ke-3 terdiri dari 7 kalimat
# ➡️ Paragraf ke-4 terdiri dari 5 kalimat
# ➡️ Paragraf ke-5 terdiri dari 8 kalimat
# ➡️ Paragraf ke-6 terdiri dari 4 kalimat
# --------------------------------------------------
#
# 📘 Bagian: Kesimpulan
# Jumlah paragraf: 2
#
# ➡️ Paragraf ke-1 terdiri dari 3 kalimat
# ➡️ Paragraf ke-2 terdiri dari 2 kalimat
# --------------------------------------------------

# %% [markdown]
# **INTERPETASI JUMLAH KALIMAT per PARAGRAF**
#
# * Abstrak hanya terdiri dari satu paragraf panjang dengan 9 kalimat. Ini khas untuk abstrak ilmiah, karena biasanya memuat latar belakang, metode, hasil, dan kesimpulan secara ringkas dalam satu blok teks.
#
# * Pendahuluan memiliki struktur yang paling kompleks dengan 6 paragraf. Setiap paragraf terdiri dari 4–9 kalimat, menandakan bahwa bagian ini membahas topik secara bertahap — mulai dari latar belakang umum, data prevalensi, hingga urgensi masalah stunting.
#
# * Kesimpulan terdiri atas 2 paragraf pendek (masing-masing 2–3 kalimat), menandakan fokus pada pernyataan hasil dan rekomendasi tanpa banyak penjabaran tambahan.
#
# Dari histogram, tampak bahwa:
#
# * Frekuensi tertinggi berada pada 5–6 kalimat per paragraf.
#
# * Paragraf dengan kalimat sedikit (2–3) dan sangat panjang (9–10) jumlahnya lebih sedikit.
#
# * Sebagian besar paragraf berada dalam rentang 4–7 kalimat, yang merupakan jumlah ideal untuk teks ilmiah karena menjaga keseimbangan antara kedalaman isi dan keterbacaan.
